# %% [markdown]
# #### Step 1 导入相关包

# %%
from tqdm import tqdm
from collections import defaultdict,Counter
import pickle
import numpy as np
from cso_classifier import CSOClassifier

import re

# %% [markdown]
# #### Step 2 加载数据

# %%
with open('./data/filter_ai_papers.pkl', 'rb') as f:
    filter_ai_papers = pickle.load(f)

# %%
with open('./data/filter_ai_papers_0312.pkl', 'rb') as f:
    full_filter_ai_papers = pickle.load(f)

# %%
# 计算差集（找出新增的论文）
new_papers = {paper_id: paper_info for paper_id, paper_info in full_filter_ai_papers.items() if paper_id not in filter_ai_papers}

# %%
# 处理新增的论文，转换为所需格式
new_papers_title_abstract = {}
for paper_id, paper_info in tqdm(new_papers.items()):
    new_papers_title_abstract[paper_id] = {
        'title': paper_info.get('title', '').replace('<i>', '').replace('</i>', ''),  # 去除HTML标签
        'abstract': paper_info.get('abstract', ''),
    }
# Out:
# 100%|██████████| 321976/321976 [00:00<00:00, 1003034.97it/s]

# %%
# 转换为所需格式
papers_title_abstract = {}
for paper_id, paper_info in tqdm(filter_ai_papers.items()):
    papers_title_abstract[paper_id] = {
        'title': paper_info.get('title', '').replace('<i>', '').replace('</i>', ''),  # 去除HTML标签
        'abstract': paper_info.get('abstract', ''),  
    }
# Out:
# 100%|██████████| 1055544/1055544 [00:00<00:00, 1090051.21it/s]

# %% [markdown]
# #### Step 3 识别论文

# %%
# 初始化分类器
cc = CSOClassifier(workers=1, modules="both", enhancement="first", explanation=True,fast_classification=True)

# %%
def process_in_batches(papers, batch_size=20, save_interval=100000, save_path='./data/cso_result.pkl'):
    # 获取论文的ID列表
    paper_ids = list(papers.keys())
    total_papers = len(paper_ids)
    results = {}
    papers_processed = 0  # 记录已处理的论文数量

    # 按批次处理论文
    for i in tqdm(range(0, total_papers, batch_size)):
        # 获取当前批次的论文ID
        batch_ids = paper_ids[i:i + batch_size]
        batch_papers = {paper_id: papers[paper_id] for paper_id in batch_ids}

        # 调用 batch_run 方法处理当前批次
        batch_result = cc.batch_run(batch_papers)
        results.update(batch_result)  # 将结果合并到总结果中

        # 更新已处理的论文数量
        papers_processed += len(batch_ids)

        # 每处理一定数量的论文，保存结果到本地
        if papers_processed >= save_interval:
            with open(save_path, "wb") as f:
                pickle.dump(results, f)
            print(f"Saved results to {save_path} after processing {papers_processed} papers.")
            papers_processed = 0  # 重置计数器

    # 保存最终结果
    if results:
        with open(save_path, "wb") as f:
            pickle.dump(results, f)
        print(f"Final results saved to {save_path}.")

    return results

# %%
# 处理论文数据，分批次运行
batch_size = 20
save_interval = 100000
save_path = './data/cso_result.pkl'  # 保存路径
results = process_in_batches(papers_title_abstract, batch_size=batch_size, save_interval=save_interval, save_path=save_path)

# 打印结果
print("处理完了")
# Out:
#   9%|▉         | 5000/52778 [7:07:41<71:19:16,  5.37s/it]
# Saved results to ./data/cso_result.pkl after processing 100000 papers.
#  19%|█▉        | 10000/52778 [14:18:00<66:39:26,  5.61s/it]
# Saved results to ./data/cso_result.pkl after processing 100000 papers.
#  28%|██▊       | 15000/52778 [21:34:42<59:43:07,  5.69s/it]
# Saved results to ./data/cso_result.pkl after processing 100000 papers.
#  38%|███▊      | 20000/52778 [28:44:36<58:25:43,  6.42s/it]
# Saved results to ./data/cso_result.pkl after processing 100000 papers.
#  47%|████▋     | 25000/52778 [35:51:58<51:39:05,  6.69s/it]
# Saved results to ./data/cso_result.pkl after processing 100000 papers.
#  57%|█████▋    | 30000/52778 [42:59:39<46:44:09,  7.39s/it]
# Saved results to ./data/cso_result.pkl after processing 100000 papers.
#  66%|██████▋   | 35000/52778 [50:27:05<34:11:56,  6.93s/it]
# Saved results to ./data/cso_result.pkl after processing 100000 papers.
#  76%|███████▌  | 40000/52778 [57:52:00<30:08:44,  8.49s/it]
# Saved results to ./data/cso_result.pkl after processing 100000 papers.
#  85%|████████▌ | 45000/52778 [65:36:34<18:00:49,  8.34s/it]
# Saved results to ./data/cso_result.pkl after processing 100000 papers.
#  95%|█████████▍| 50000/52778 [73:25:17<6:55:00,  8.96s/it]
# Saved results to ./data/cso_result.pkl after processing 100000 papers.
# 100%|██████████| 52778/52778 [77:42:54<00:00,  5.30s/it]
# Final results saved to ./data/cso_result.pkl.
# 处理完了

# %% [markdown]
# #### Step 4 识别增补论文

# %%
def process_in_batches_add(papers, batch_size=20, save_interval=100000, save_path='./data/cso_result_add.pkl'):
    # 获取论文的ID列表
    paper_ids = list(papers.keys())
    total_papers = len(paper_ids)
    results = {}
    papers_processed = 0  # 记录已处理的论文数量

    # 按批次处理论文
    for i in tqdm(range(0, total_papers, batch_size)):
        # 获取当前批次的论文ID
        batch_ids = paper_ids[i:i + batch_size]
        batch_papers = {paper_id: papers[paper_id] for paper_id in batch_ids}

        try:
            # 调用 batch_run 方法处理当前批次
            batch_result = cc.batch_run(batch_papers)
            results.update(batch_result)  # 将结果合并到总结果中
        except Exception as e:
            # 捕获并记录错误信息
            print(f"Error processing batch starting at paper ID {batch_ids[0]}: {e}")
            continue  # 跳过当前批次，继续处理下一个批次

        # 更新已处理的论文数量
        papers_processed += len(batch_ids)

        # 每处理一定数量的论文，保存结果到本地
        if papers_processed >= save_interval:
            with open(save_path, "wb") as f:
                pickle.dump(results, f)
            print(f"Saved results to {save_path} after processing {papers_processed} papers.")
            papers_processed = 0  # 重置计数器

    # 保存最终结果
    if results:
        with open(save_path, "wb") as f:
            pickle.dump(results, f)
        print(f"Final results saved to {save_path}.")

    return results

# %%
# 处理论文数据，分批次运行
batch_size = 20
save_interval = 100000
save_path = './data/cso_result_add.pkl'  # 保存路径
results = process_in_batches_add(new_papers_title_abstract, batch_size=batch_size, save_interval=save_interval, save_path=save_path)

# 打印结果
print("处理完了")
# Out:
#  31%|███       | 5000/16099 [7:44:07<18:47:12,  6.09s/it]
# Saved results to ./data/cso_result_add.pkl after processing 100000 papers.
#  62%|██████▏   | 10000/16099 [15:36:56<11:12:57,  6.62s/it]
# Saved results to ./data/cso_result_add.pkl after processing 100000 papers.
#  93%|█████████▎| 15000/16099 [23:59:42<2:05:07,  6.83s/it]
# Saved results to ./data/cso_result_add.pkl after processing 100000 papers.
# 100%|██████████| 16099/16099 [25:50:05<00:00,  5.78s/it]
# Final results saved to ./data/cso_result_add.pkl.
# 处理完了

# %%
results
# Out:
# {'W4293022965': {'syntactic': ['classification models',
#    'computer hardware',
#    'neural networks',
#    'demonstrations',
#    'computing systems'],
#   'semantic': ['classification methods',
#    'computer hardware',
#    'neural networks',
#    'correlation analysis',
#    'demonstrations',
#    'random access memory',
#    'computing systems'],
#   'union': ['classification models',
#    'classification methods',
#    'computer hardware',
#    'neural networks',
#    'correlation analysis',
#    'demonstrations',
#    'random access memory',
#    'computing systems'],
#   'enhanced': ['computer systems',
#    'computer science',
#    'machine learning',
#    'mathematics',
#    'information systems',
#    'education',
#    'random access storage'],
#   'explanation': {'demonstrations': ['demonstration'],
#    'computing systems': ['computing systems'],
#    'computer hardware': ['hardware',
#     'calibrating hardware noise',
#     'hardware noise',
#     'hardware measurements',
#     'calibrating hardware'],
#    'neural networks': ['neural network'],
#    'classification models': ['classifications model'],
#    'random access memory': ['memory technologies',
#     'memory computing',
#     'memory'],
#    'correlation analysis': ['statistical computing', 'statistical'],
#    'classification methods': ['classifications model',
#     '100 classifications',
#     'classifications'],
#    'computer systems': ['classifications model',
#     'computing systems',
#     '100 classifications',
#     'classifications'],
#    'computer science': ['hardware',
#     'calibrating hardware noise',
#     'hardware noise',
#     'hardware measurements',
#     'calibrating hardware'],
#    'machine learning': ['neural network'],
#    'mathematics': ['statistical computing', 'statistical'],
#    'information systems': ['demonstration'],
#    'education': ['demonstration'],
#    'random access storage': ['memory technologies',
#     'memory computing',
#     'memory']}},
#  'W4293261795': {'syntactic': ['safety critical applications',
#    'self-driving auto',
#    'convolutional neural networks',
#    'fault-tolerant',
#    'fault tolerance',
#    'neural networks',
#    'bit error rate',
#    'classifiers',
#    'technology scaling'],
#   'semantic': ['self-driving auto',
#    'deep belief networks',
#    'fault tolerance',
#    'neural networks',
#    'svm',
#    'bit error rate',
#    'vehicles',
#    'classifiers',
#    'technology scaling',
#    'network architecture'],
#   'union': ['safety critical applications',
#    'self-driving auto',
#    'convolutional neural networks',
#    'fault-tolerant',
#    'deep belief networks',
#    'fault tolerance',
#    'neural networks',
#    'svm',
#    'bit error rate',
#    'vehicles',
#    'classifiers',
#    'technology scaling',
#    'network architecture'],
#   'enhanced': ['real time systems',
#    'motion planning',
#    'computer vision',
#    'fault tolerant computer systems',
#    'bayesian methods',
#    'deep learning',
#    'software quality',
#    'machine learning',
#    'support vector machine',
#    'communication channels',
#    'signal to noise ratio',
#    'probability',
#    'engineering',
#    'classification',
#    'process variation',
#    'static random access storage',
#    'low power',
#    'computer networks'],
#   'explanation': {'classifiers': ['classifier',
#     'vector classifier',
#     'dnn classifier'],
#    'neural networks': ['convolutional neural network',
#     'neural network',
#     'cnn',
#     'neural networks'],
#    'fault-tolerant': ['fault-tolerant'],
#    'safety critical applications': ['safety-critical applications'],
#    'self-driving auto': ['autonomous vehicles'],
#    'technology scaling': ['technology scaling'],
#    'convolutional neural networks': ['convolutional neural network', 'cnn'],
#    'fault tolerance': ['fault tolerance'],
#    'bit error rate': ['bit error rate', 'error rate'],
#    'vehicles': ['autonomous vehicles', 'vehicles'],
#    'svm': ['classifier', 'vector classifier', 'dnn classifier'],
#    'deep belief networks': ['deep neural networks',
#     'convolutional neural network',
#     'dnns'],
#    'network architecture': ['architectures', 'networks', 'network'],
#    'real time systems': ['safety-critical applications'],
#    'motion planning': ['autonomous vehicles'],
#    'computer vision': ['autonomous vehicles'],
#    'fault tolerant computer systems': ['fault-tolerant', 'fault tolerance'],
#    'bayesian methods': ['deep neural networks',
#     'convolutional neural network',
#     'dnns'],
#    'deep learning': ['deep neural networks',
#     'convolutional neural network',
#     'dnns'],
#    'software quality': ['fault tolerance'],
#    'machine learning': ['classifier',
#     'neural network',
#     'dnn classifier',
#     'neural networks',
#     'convolutional neural network',
#     'vector classifier',
#     'cnn'],
#    'support vector machine': ['classifier',
#     'vector classifier',
#     'dnn classifier'],
#    'communication channels': ['bit error rate', 'error rate'],
#    'signal to noise ratio': ['bit error rate', 'error rate'],
#    'probability': ['bit error rate', 'error rate'],
#    'engineering': ['autonomous vehicles', 'vehicles'],
#    'classification': ['classifier', 'vector classifier', 'dnn classifier'],
#    'process variation': ['technology scaling'],
#    'static random access storage': ['technology scaling'],
#    'low power': ['technology scaling'],
#    'computer networks': ['architectures', 'networks', 'network']}},
#  'W4385261426': {'syntactic': ['parallelism',
#    'genetic selection',
#    'computer hardware',
#    'neural networks'],
#   'semantic': ['co-processors',
#    'parallelism',
#    'computer hardware',
#    'neural networks',
#    'communication',
#    'hardware accelerators'],
#   'union': ['co-processors',
#    'parallelism',
#    'genetic selection',
#    'communication',
#    'hardware accelerators',
#    'computer hardware',
#    'neural networks'],
#   'enhanced': ['field programmable gate array',
#    'program processors',
#    'parallel programming',
#    'genetic analysis',
#    'computer science',
#    'machine learning'],
#   'explanation': {'parallelism': ['parallelism', 'level parallelism'],
#    'neural networks': ['neural networks'],
#    'computer hardware': ['hardware',
#     'aware accelerator',
#     'accelerator systems',
#     'accelerators',
#     'accelerator selection',
#     'multi accelerator',
#     'accelerator',
#     'hardware system'],
#    'genetic selection': ['selection'],
#    'hardware accelerators': ['accelerators',
#     'aware accelerator',
#     'accelerator selection',
#     'multi accelerator',
#     'accelerator',
#     'accelerator systems'],
#    'co-processors': ['accelerators',
#     'aware accelerator',
#     'accelerator selection',
#     'multi accelerator',
#     'accelerator',
#     'accelerator systems'],
#    'communication': ['communication'],
#    'field programmable gate array': ['accelerators',
#     'aware accelerator',
#     'accelerator selection',
#     'multi accelerator',
#     'accelerator',
#     'accelerator systems'],
#    'program processors': ['accelerators',
#     'aware accelerator',
#     'accelerator selection',
#     'multi accelerator',
#     'accelerator',
#     'accelerator systems'],
#    'parallel programming': ['parallelism', 'level parallelism'],
#    'genetic analysis': ['selection'],
#    'computer science': ['hardware',
#     'aware accelerator',
#     'accelerator systems',
#     'accelerators',
#     'accelerator selection',
#     'multi accelerator',
#     'accelerator',
#     'hardware system'],
#    'machine learning': ['neural networks']}},
#  'W4293025109': {'syntactic': ['inference',
#    'encoder-decoder',
#    'computer hardware',
#    'neural networks',
#    'look-up table'],
#   'semantic': ['inference',
#    'computer hardware',
#    'neural networks',
#    'parallel computation',
#    'look-up table'],
#   'union': ['look-up table',
#    'inference',
#    'parallel computation',
#    'encoder-decoder',
#    'computer hardware',
#    'neural networks'],
#   'enhanced': ['table lookup',
#    'inference engines',
#    'parallel algorithms',
#    'parallel computing',
#    'deep learning',
#    'computer science',
#    'machine learning'],
#   'explanation': {'encoder-decoder': ['transformer'],
#    'look-up table': ['look-up tables',
#     'lut',
#     'nn lut',
#     'lut(nn lut',
#     'look-up table'],
#    'computer hardware': ['hardware',
#     'hardware cost',
#     'considerable hardware',
#     'considerable hardware cost'],
#    'inference': ['inference', 'transformer inference'],
#    'neural networks': ['neural network'],
#    'parallel computation': ['computations', 'integer computations'],
#    'table lookup': ['look-up tables',
#     'lut',
#     'nn lut',
#     'lut(nn lut',
#     'look-up table'],
#    'inference engines': ['inference', 'transformer inference'],
#    'parallel algorithms': ['computations', 'integer computations'],
#    'parallel computing': ['computations', 'integer computations'],
#    'deep learning': ['transformer'],
#    'computer science': ['hardware',
#     'hardware cost',
#     'considerable hardware',
#     'considerable hardware cost'],
#    'machine learning': ['neural network']}},
#  'W4386763995': {'syntactic': ['embedded systems',
#    'inference',
#    'artificial intelligence',
#    'computer vision',
#    'encoder-decoder',
#    'attention mechanism',
#    'dram',
#    'neural networks',
#    'natural language processing'],
#   'semantic': ['probabilistic inference',
#    'memory architecture',
#    'co-processors',
#    'inference',
#    'artificial intelligence',
#    'computer vision',
#    'dram',
#    'neural networks',
#    'computer hardware',
#    'architecture designs',
#    'natural languages',
#    'sram cell',
#    'software',
#    'natural language processing',
#    'hardware accelerators'],
#   'union': ['memory architecture',
#    'co-processors',
#    'artificial intelligence',
#    'encoder-decoder',
#    'natural languages',
#    'sram cell',
#    'hardware accelerators',
#    'embedded systems',
#    'inference',
#    'computer vision',
#    'attention mechanism',
#    'dram',
#    'neural networks',
#    'computer hardware',
#    'architecture designs',
#    'software',
#    'natural language processing',
#    'probabilistic inference'],
#   'enhanced': ['field programmable gate array',
#    'multi core',
#    'parallel architectures',
#    'program processors',
#    'computer science',
#    'deep learning',
#    'linguistics',
#    'semantics',
#    'static random access storage',
#    'integrated circuits',
#    'low power',
#    'computer systems',
#    'inference engines',
#    'computer imaging and vision',
#    'dynamic random access storage',
#    'machine learning',
#    'software architecture',
#    'bayesian methods',
#    'probability distributions'],
#   'explanation': {'dram': ['sram', 'dram', 'memory architecture'],
#    'encoder-decoder': ['transformer-based', 'transformer'],
#    'attention mechanism': ['attention mechanism'],
#    'neural networks': ['neural networks'],
#    'artificial intelligence': ['natural language processing',
#     'artificial intelligence',
#     'language processing'],
#    'natural language processing': ['natural language processing',
#     'language processing'],
#    'computer vision': ['computer vision'],
#    'inference': ['inference latency', 'inference', 'transformer inference'],
#    'embedded systems': ['embedded systems'],
#    'memory architecture': ['memory architecture'],
#    'natural languages': ['natural language',
#     'natural language processing',
#     'language processing'],
#    'probabilistic inference': ['inference latency',
#     'inference',
#     'transformer inference'],
#    'computer hardware': ['hardware',
#     'dram accelerator',
#     'hardware software co',
#     'software',
#     'accelerator',
#     'hardware software'],
#    'software': ['software co', 'software', 'hardware software'],
#    'sram cell': ['sram', 'hybrid sram'],
#    'hardware accelerators': ['dram accelerator', 'accelerator'],
#    'co-processors': ['dram accelerator', 'accelerator'],
#    'architecture designs': ['architecture', 'design'],
#    'field programmable gate array': ['dram accelerator',
#     'memory architecture',
#     'accelerator'],
#    'multi core': ['memory architecture'],
#    'parallel architectures': ['memory architecture'],
#    'program processors': ['dram accelerator', 'accelerator'],
#    'computer science': ['dram accelerator',
#     'hardware',
#     'artificial intelligence',
#     'software co',
#     'hardware software co',
#     'software',
#     'accelerator',
#     'hardware software'],
#    'deep learning': ['transformer-based',
#     'transformer',
#     'attention mechanism'],
#    'linguistics': ['natural language'],
#    'semantics': ['natural language'],
#    'static random access storage': ['sram', 'hybrid sram'],
#    'integrated circuits': ['sram', 'hybrid sram'],
#    'low power': ['sram', 'hybrid sram'],
#    'computer systems': ['embedded systems'],
#    'inference engines': ['inference',
#     'transformer inference',
#     'inference latency'],
#    'computer imaging and vision': ['computer vision'],
#    'dynamic random access storage': ['sram', 'dram', 'memory architecture'],
#    'machine learning': ['neural networks'],
#    'software architecture': ['architecture', 'design'],
#    'bayesian methods': ['inference latency',
#     'inference',
#     'transformer inference'],
#    'probability distributions': ['inference latency',
#     'inference',
#     'transformer inference']}},
#  'W4293261679': {'syntactic': ['support vector machine',
#    'detection algorithm',
#    'autoencoders',
#    'design space exploration'],
#   'semantic': ['machine learning',
#    'internet',
#    'detection algorithm',
#    'support vector',
#    'design space exploration',
#    'support vector machine'],
#   'union': ['autoencoders',
#    'detection algorithm',
#    'support vector',
#    'machine learning',
#    'support vector machine',
#    'internet',
#    'design space exploration'],
#   'enhanced': ['deep learning',
#    'unsupervised learning',
#    'signal detection',
#    'artificial intelligence',
#    'classifiers',
#    'computer science',
#    'embedded systems',
#    'microprocessor chips'],
#   'explanation': {'detection algorithm': ['detection method',
#     'detection algorithms',
#     'detection process',
#     'detection'],
#    'support vector machine': ['support vector machine',
#     'vector machine',
#     'support vector'],
#    'autoencoders': ['autoencoder'],
#    'design space exploration': ['design space', 'design space exploration'],
#    'internet': ['internet'],
#    'machine learning': ['machine learning'],
#    'support vector': ['vector machine', 'support vector'],
#    'deep learning': ['autoencoder'],
#    'unsupervised learning': ['autoencoder'],
#    'signal detection': ['detection method',
#     'detection',
#     'detection process',
#     'detection algorithms'],
#    'artificial intelligence': ['machine learning'],
#    'classifiers': ['vector machine',
#     'support vector',
#     'support vector machine'],
#    'computer science': ['internet'],
#    'embedded systems': ['design space', 'design space exploration'],
#    'microprocessor chips': ['design space', 'design space exploration']}},
#  'W4293024055': {'syntactic': ['fault-tolerant',
#    'random access memory',
#    'optimization problems',
#    'neural networks'],
#   'semantic': ['co-processors',
#    'optimization',
#    'neural networks',
#    'hardware accelerators',
#    'random access memory',
#    'optimization problems'],
#   'union': ['co-processors',
#    'fault-tolerant',
#    'optimization',
#    'hardware accelerators',
#    'random access memory',
#    'optimization problems',
#    'neural networks'],
#   'enhanced': ['field programmable gate array',
#    'program processors',
#    'fault tolerant computer systems',
#    'mathematics',
#    'computer hardware',
#    'random access storage',
#    'correlation analysis',
#    'machine learning'],
#   'explanation': {'fault-tolerant': ['fault-tolerant'],
#    'neural networks': ['neural network'],
#    'random access memory': ['access memory',
#     'memory',
#     'memory crossbars',
#     'random access memory'],
#    'optimization problems': ['systematic optimization',
#     'optimization',
#     'optimization method'],
#    'optimization': ['optimization', 'optimization method'],
#    'hardware accelerators': ['network accelerator', 'accelerator'],
#    'co-processors': ['network accelerator', 'accelerator'],
#    'field programmable gate array': ['network accelerator', 'accelerator'],
#    'program processors': ['network accelerator', 'accelerator'],
#    'fault tolerant computer systems': ['fault-tolerant'],
#    'mathematics': ['optimization', 'optimization method'],
#    'computer hardware': ['network accelerator', 'accelerator'],
#    'random access storage': ['access memory',
#     'memory crossbars',
#     'random access memory',
#     'memory'],
#    'correlation analysis': ['systematic optimization',
#     'optimization',
#     'optimization method'],
#    'machine learning': ['neural network']}},
#  'W4293024216': {'syntactic': ['sparse matrix-vector multiplication',
#    'bandwidth efficiency',
#    'high bandwidth',
#    'sparse matrices',
#    'general purpose',
#    'fpgas',
#    'deep learning',
#    'multiplier',
#    'gpu'],
#   'semantic': ['bandwidth efficiency',
#    'random access memory',
#    'high bandwidth',
#    'sparse matrices',
#    'general purpose',
#    'fpgas',
#    'multiplication',
#    'deep learning',
#    'bandwidth',
#    'multiplier',
#    'gpu'],
#   'union': ['sparse matrix-vector multiplication',
#    'bandwidth efficiency',
#    'high bandwidth',
#    'sparse matrices',
#    'general purpose',
#    'fpgas',
#    'multiplier',
#    'multiplication',
#    'deep learning',
#    'bandwidth',
#    'random access memory',
#    'gpu'],
#   'enhanced': ['block codes',
#    'telecommunication systems',
#    'matrix algebra',
#    'program processors',
#    'reconfigurable architectures',
#    'frequency multiplying circuits',
#    'multiplying circuits',
#    'neural networks',
#    'computer networks',
#    'random access storage'],
#   'explanation': {'sparse matrix-vector multiplication': ['sparse matrix-vector multiplication'],
#    'multiplier': ['multiplication', 'multiplies'],
#    'sparse matrices': ['sparse matrix-vector multiplication',
#     'spmv',
#     'sparse matrix'],
#    'deep learning': ['deep learning'],
#    'high bandwidth': ['high bandwidth'],
#    'fpgas': ['fpgas'],
#    'general purpose': ['general purpose', 'general-purpose'],
#    'gpu': ['sparse matrix-vector multiplication', 'gpu'],
#    'bandwidth efficiency': ['bandwidth efficiency'],
#    'multiplication': ['multiplication', 'vector multiplication'],
#    'random access memory': ['random memory',
#     'bandwidth memory',
#     'memory',
#     'memory centric'],
#    'bandwidth': ['bandwidth memory',
#     'bandwidth efficiency',
#     'high bandwidth',
#     'bandwidth',
#     'high bandwidth memory'],
#    'block codes': ['bandwidth efficiency'],
#    'telecommunication systems': ['high bandwidth'],
#    'matrix algebra': ['sparse matrix-vector multiplication',
#     'spmv',
#     'sparse matrix'],
#    'program processors': ['sparse matrix-vector multiplication',
#     'general-purpose',
#     'general purpose',
#     'gpu'],
#    'reconfigurable architectures': ['fpgas'],
#    'frequency multiplying circuits': ['multiplication', 'multiplies'],
#    'multiplying circuits': ['multiplication', 'vector multiplication'],
#    'neural networks': ['deep learning'],
#    'computer networks': ['bandwidth efficiency',
#     'bandwidth memory',
#     'high bandwidth',
#     'bandwidth',
#     'high bandwidth memory'],
#    'random access storage': ['random memory',
#     'bandwidth memory',
#     'memory',
#     'memory centric']}},
#  'W4293024179': {'syntactic': ['process variation',
#    'attention mechanism',
#    'resolution enhancement',
#    'enhancement techniques',
#    'reinforcement learning'],
#   'semantic': ['process variation',
#    'frequency bands',
#    'resolution enhancement',
#    'enhancement techniques',
#    'reinforcement learning',
#    'gpu'],
#   'union': ['frequency bands',
#    'resolution enhancement',
#    'process variation',
#    'enhancement techniques',
#    'attention mechanism',
#    'reinforcement learning',
#    'gpu'],
#   'enhanced': ['antennas',
#    'superresolution',
#    'image resolution',
#    'image enhancement',
#    'integrated circuits',
#    'computer aided design',
#    'microprocessor chips',
#    'speech enhancement',
#    'deep learning',
#    'machine learning',
#    'program processors'],
#   'explanation': {'enhancement techniques': ['enhancement techniques (',
#     'enhancement',
#     'enhancement techniques'],
#    'resolution enhancement': ['resolution enhancement'],
#    'attention mechanism': ['attention mechanism'],
#    'reinforcement learning': ['reinforcement-learning',
#     'reinforcement learning'],
#    'process variation': ['process variation'],
#    'gpu': ['gpu'],
#    'frequency bands': ['variation band', 'band'],
#    'antennas': ['variation band', 'band'],
#    'superresolution': ['resolution enhancement'],
#    'image resolution': ['resolution enhancement'],
#    'image enhancement': ['enhancement',
#     'enhancement techniques (',
#     'resolution enhancement',
#     'enhancement techniques'],
#    'integrated circuits': ['process variation'],
#    'computer aided design': ['process variation'],
#    'microprocessor chips': ['process variation'],
#    'speech enhancement': ['enhancement techniques (',
#     'enhancement',
#     'enhancement techniques'],
#    'deep learning': ['attention mechanism'],
#    'machine learning': ['reinforcement-learning', 'reinforcement learning'],
#    'program processors': ['gpu']}},
#  'W1978000252': {'syntactic': ['circuit topology', 'computer aided design'],
#   'semantic': ['topology',
#    'integrated circuit layout',
#    'computer aided design',
#    'circuit topology',
#    'flip flop circuits'],
#   'union': ['circuit topology',
#    'topology',
#    'flip flop circuits',
#    'integrated circuit layout',
#    'computer aided design'],
#   'enhanced': ['electric network topology',
#    'electric network analysis',
#    'logic gates',
#    'logic design',
#    'integrated circuit testing',
#    'vlsi circuits',
#    'microprocessor chips',
#    'computer science'],
#   'explanation': {'computer aided design': ['layout', 'cad', 'cad program'],
#    'circuit topology': ['circuit topology'],
#    'topology': ['topology'],
#    'integrated circuit layout': ['layout'],
#    'flip flop circuits': ['circuit'],
#    'electric network topology': ['circuit topology'],
#    'electric network analysis': ['circuit'],
#    'logic gates': ['circuit'],
#    'logic design': ['circuit'],
#    'integrated circuit testing': ['circuit'],
#    'vlsi circuits': ['layout'],
#    'microprocessor chips': ['layout'],
#    'computer science': ['layout', 'cad', 'cad program']}},
#  'W4386765215': {'syntactic': ['encoders',
#    'computer hardware',
#    'network intrusion detection',
#    'cyber threats',
#    'high dimensionality',
#    'deep learning',
#    'cyber security'],
#   'semantic': ['computer hardware',
#    'intrusion detection',
#    'network intrusion detection',
#    'cyber threats',
#    'deep learning',
#    'cyber security'],
#   'union': ['encoders',
#    'computer hardware',
#    'intrusion detection',
#    'network intrusion detection',
#    'cyber threats',
#    'high dimensionality',
#    'deep learning',
#    'cyber security'],
#   'enhanced': ['computer science',
#    'computer crime',
#    'network security',
#    'feature selection',
#    'neural networks'],
#   'explanation': {'network intrusion detection': ['network intrusion detection',
#     'intrusion',
#     'intrusion detection'],
#    'cyber security': ['cyber threats', 'cyber', 'threats', 'cybersecurity'],
#    'deep learning': ['deep learning', 'encoders'],
#    'cyber threats': ['cyber threats', 'cyber', 'threats', 'cybersecurity'],
#    'encoders': ['encoders'],
#    'high dimensionality': ['high dimensionality'],
#    'computer hardware': ['hardware', 'hardware errors'],
#    'intrusion detection': ['network intrusion detection',
#     'intrusion',
#     'network intrusion',
#     'intrusion detection'],
#    'computer science': ['hardware', 'hardware errors'],
#    'computer crime': ['network intrusion detection',
#     'intrusion',
#     'cyber threats',
#     'cyber',
#     'threats',
#     'network intrusion',
#     'cybersecurity',
#     'intrusion detection'],
#    'network security': ['cyber', 'threats', 'cybersecurity', 'cyber threats'],
#    'feature selection': ['high dimensionality'],
#    'neural networks': ['deep learning', 'encoders']}},
#  'W4386764212': {'syntactic': ['computing resource',
#    'energy-efficient',
#    'cim',
#    'neural networks'],
#   'semantic': ['co-processors',
#    'computing resource',
#    'cim',
#    'neural networks',
#    'hardware accelerators'],
#   'union': ['co-processors',
#    'computing resource',
#    'hardware accelerators',
#    'energy-efficient',
#    'cim',
#    'neural networks'],
#   'enhanced': ['field programmable gate array',
#    'program processors',
#    'cloud computing',
#    'computer hardware',
#    'sensor networks',
#    'wireless sensor networks',
#    'telecommunication equipment',
#    'computer integrated manufacturing',
#    'machine learning'],
#   'explanation': {'neural networks': ['neural network'],
#    'cim': ['cim'],
#    'computing resource': ['computing platform'],
#    'energy-efficient': ['energy-efficient'],
#    'hardware accelerators': ['accelerators',
#     'network accelerator',
#     'accelerator'],
#    'co-processors': ['accelerators', 'network accelerator', 'accelerator'],
#    'field programmable gate array': ['accelerators',
#     'network accelerator',
#     'accelerator'],
#    'program processors': ['accelerators',
#     'network accelerator',
#     'accelerator'],
#    'cloud computing': ['computing platform'],
#    'computer hardware': ['accelerators', 'network accelerator', 'accelerator'],
#    'sensor networks': ['energy-efficient'],
#    'wireless sensor networks': ['energy-efficient'],
#    'telecommunication equipment': ['energy-efficient'],
#    'computer integrated manufacturing': ['cim'],
#    'machine learning': ['neural network']}},
#  'W4386765260': {'syntactic': ['budgets',
#    'efficient computation',
#    'convolutional neural networks'],
#   'semantic': ['budgets',
#    'non-volatile memories',
#    'neural networks',
#    'efficient computation',
#    'random access memory'],
#   'union': ['convolutional neural networks',
#    'efficient computation',
#    'budgets',
#    'random access memory',
#    'non-volatile memories',
#    'neural networks'],
#   'enhanced': ['computational efficiency',
#    'economics',
#    'research support',
#    'random access storage',
#    'flash memory',
#    'machine learning'],
#   'explanation': {'efficient computation': ['computation',
#     'efficient computation'],
#    'convolutional neural networks': ['convolutional neural networks'],
#    'budgets': ['budgets', 'budget'],
#    'random access memory': ['memory computing', 'memory'],
#    'neural networks': ['convolutional neural networks', 'neural networks'],
#    'non-volatile memories': ['memory'],
#    'computational efficiency': ['computation', 'efficient computation'],
#    'economics': ['budgets', 'budget'],
#    'research support': ['budgets', 'budget'],
#    'random access storage': ['memory computing', 'memory'],
#    'flash memory': ['memory'],
#    'machine learning': ['convolutional neural networks', 'neural networks']}},
#  'W1978378184': {'syntactic': [],
#   'semantic': ['logic gates',
#    'heuristic approaches',
#    'assignment problems',
#    'meta-heuristic methods',
#    'mathematics'],
#   'union': ['logic gates',
#    'meta-heuristic methods',
#    'mathematics',
#    'heuristic approaches',
#    'assignment problems'],
#   'enhanced': ['field programmable gate array',
#    'particle swarm optimization (pso)',
#    'heuristic programming',
#    'combinatorial optimization'],
#   'explanation': {'heuristic approaches': ['heuristic', 'heuristic methods'],
#    'logic gates': ['gate'],
#    'assignment problems': ['assignment'],
#    'meta-heuristic methods': ['heuristic methods'],
#    'mathematics': ['mathematical'],
#    'field programmable gate array': ['gate'],
#    'particle swarm optimization (pso)': ['heuristic methods'],
#    'heuristic programming': ['heuristic', 'heuristic methods'],
#    'combinatorial optimization': ['assignment']}},
#  'W4386763819': {'syntactic': ['real time systems', 'sensor data'],
#   'semantic': ['sensors',
#    'real time systems',
#    'integrated data',
#    'optimization problems',
#    'sensor data'],
#   'union': ['sensor data',
#    'real time systems',
#    'integrated data',
#    'optimization problems',
#    'sensors'],
#   'enhanced': ['knowledge based systems',
#    'object oriented programming',
#    'mobile robots',
#    'field programmable gate array',
#    'embedded systems',
#    'online systems',
#    'digital signal processing',
#    'data integration',
#    'correlation analysis',
#    'computer hardware'],
#   'explanation': {'real time systems': ['real-time systems',
#     'real time systems'],
#    'sensor data': ['sensor data'],
#    'sensors': ['sensor', 'sensor data'],
#    'integrated data': ['data'],
#    'optimization problems': ['techniques'],
#    'knowledge based systems': ['real-time systems', 'real time systems'],
#    'object oriented programming': ['real-time systems', 'real time systems'],
#    'mobile robots': ['real-time systems', 'real time systems'],
#    'field programmable gate array': ['real-time systems', 'real time systems'],
#    'embedded systems': ['real-time systems', 'real time systems'],
#    'online systems': ['real-time systems', 'real time systems'],
#    'digital signal processing': ['real-time systems', 'real time systems'],
#    'data integration': ['data'],
#    'correlation analysis': ['techniques'],
#    'computer hardware': ['sensor', 'sensor data']}},
#  'W4360837211': {'syntactic': ['image segmentation',
#    'convolutional neural networks',
#    'encoder-decoder',
#    'segmentation methods',
#    'manhattans',
#    'privacy',
#    'clustering algorithms',
#    'supervised machine learning'],
#   'semantic': ['image segmentation',
#    'neural networks',
#    'segmentation methods',
#    'manhattans',
#    'privacy',
#    'clustering algorithms'],
#   'union': ['image segmentation',
#    'convolutional neural networks',
#    'encoder-decoder',
#    'neural networks',
#    'segmentation methods',
#    'manhattans',
#    'privacy',
#    'clustering algorithms',
#    'supervised machine learning'],
#   'enhanced': ['image analysis',
#    'image processing',
#    'deep learning',
#    'machine learning',
#    'mobility model',
#    'computer security',
#    'data mining'],
#   'explanation': {'image segmentation': ['segmentation',
#     'image segmentation',
#     'unsupervised image segmentation',
#     'segmentation results'],
#    'convolutional neural networks': ['convolutional neural networks'],
#    'encoder-decoder': ['encoder-decoder'],
#    'supervised machine learning': ['supervised learning'],
#    'privacy': ['privacy'],
#    'clustering algorithms': ['clustering', 'clustering algorithm'],
#    'manhattans': ['manhattan'],
#    'segmentation methods': ['segmentation', 'segmentation results'],
#    'neural networks': ['neural network',
#     'convolutional neural networks',
#     'neural networks'],
#    'image analysis': ['segmentation',
#     'image segmentation',
#     'segmentation results',
#     'unsupervised image segmentation'],
#    'image processing': ['segmentation',
#     'image segmentation',
#     'segmentation results',
#     'unsupervised image segmentation'],
#    'deep learning': ['encoder-decoder'],
#    'machine learning': ['supervised learning',
#     'convolutional neural networks',
#     'neural network',
#     'neural networks'],
#    'mobility model': ['manhattan'],
#    'computer security': ['privacy'],
#    'data mining': ['clustering', 'clustering algorithm']}},
#  'W4386763894': {'syntactic': ['multilayer perceptrons',
#    'design flows',
#    'optimization',
#    'global feature',
#    'integrated circuits',
#    'logic synthesis',
#    'benchmark circuit'],
#   'semantic': ['multilayer perceptrons',
#    'design flows',
#    'optimization',
#    'global feature',
#    'routing scheme',
#    'logic synthesis',
#    'benchmark circuit'],
#   'union': ['multilayer perceptrons',
#    'design flows',
#    'optimization',
#    'global feature',
#    'integrated circuits',
#    'routing scheme',
#    'logic synthesis',
#    'benchmark circuit'],
#   'enhanced': ['neural networks',
#    'field programmable gate array',
#    'embedded systems',
#    'mathematics',
#    'local feature',
#    'computer hardware',
#    'routing protocols',
#    'routing algorithms',
#    'logic gates',
#    'logic design',
#    'boolean functions',
#    'computer aided design',
#    'delay circuits',
#    'application specific integrated circuits',
#    'integrated circuit testing',
#    'digital integrated circuits',
#    'timing circuits'],
#   'explanation': {'integrated circuits': ['integrated circuit ('],
#    'design flows': ['design flow'],
#    'optimization': ['optimization'],
#    'multilayer perceptrons': ['multi layer perceptron',
#     'multi-layer perceptron',
#     'perceptron',
#     'layer perceptron',
#     'mlp'],
#    'global feature': ['global features'],
#    'logic synthesis': ['logic synthesis'],
#    'benchmark circuit': ['benchmark circuits', 'iscas'],
#    'routing scheme': ['routing',
#     'routing critical path',
#     'post routing',
#     'routing critical',
#     'path',
#     'paths'],
#    'neural networks': ['multi layer perceptron',
#     'multi-layer perceptron',
#     'perceptron',
#     'layer perceptron',
#     'mlp'],
#    'field programmable gate array': ['design flow'],
#    'embedded systems': ['design flow'],
#    'mathematics': ['optimization'],
#    'local feature': ['global features'],
#    'computer hardware': ['integrated circuit ('],
#    'routing protocols': ['routing',
#     'routing critical path',
#     'post routing',
#     'routing critical',
#     'path',
#     'paths'],
#    'routing algorithms': ['routing',
#     'routing critical path',
#     'post routing',
#     'routing critical',
#     'path',
#     'paths'],
#    'logic gates': ['logic synthesis'],
#    'logic design': ['logic synthesis'],
#    'boolean functions': ['logic synthesis'],
#    'computer aided design': ['logic synthesis'],
#    'delay circuits': ['benchmark circuits', 'iscas'],
#    'application specific integrated circuits': ['benchmark circuits', 'iscas'],
#    'integrated circuit testing': ['benchmark circuits', 'iscas'],
#    'digital integrated circuits': ['benchmark circuits', 'iscas'],
#    'timing circuits': ['benchmark circuits', 'iscas']}},
#  'W4386763534': {'syntactic': ['compression ratio (machinery)',
#    'bit errors',
#    'compression methods',
#    'systolic arrays',
#    'dram',
#    'neural networks',
#    'hardware implementations',
#    'hardware accelerators'],
#   'semantic': ['compression ratio (machinery)',
#    'bit errors',
#    'compression methods',
#    'systolic arrays',
#    'dram',
#    'neural networks',
#    'hardware implementations',
#    'computer hardware',
#    'hardware accelerators'],
#   'union': ['compression ratio (machinery)',
#    'bit errors',
#    'compression methods',
#    'systolic arrays',
#    'dram',
#    'neural networks',
#    'hardware implementations',
#    'computer hardware',
#    'hardware accelerators'],
#   'enhanced': ['data compression',
#    'bit error rate',
#    'field programmable gate array',
#    'vlsi circuits',
#    'parallel processing systems',
#    'dynamic random access storage',
#    'machine learning',
#    'computer science'],
#   'explanation': {'neural networks': ['neural networks'],
#    'dram': ['dram'],
#    'compression ratio (machinery)': ['compression ratio', 'compression'],
#    'bit errors': ['bit errors'],
#    'hardware accelerators': ['hardware accelerator',
#     'inference accelerator',
#     'array accelerator',
#     'accelerator'],
#    'compression methods': ['compression ratio',
#     'compression scheme',
#     'compression'],
#    'hardware implementations': ['implementation', 'hardware implementation'],
#    'systolic arrays': ['systolic array', 'systolic'],
#    'computer hardware': ['hardware',
#     'implementation',
#     'low cost hardware',
#     'hardware implementation',
#     'hardware accelerator',
#     'cost hardware implementation',
#     'cost hardware',
#     'cost hardware accelerator',
#     'inference accelerator',
#     'array accelerator',
#     'accelerator'],
#    'data compression': ['compression scheme',
#     'compression',
#     'compression ratio'],
#    'bit error rate': ['bit errors'],
#    'field programmable gate array': ['systolic array', 'systolic'],
#    'vlsi circuits': ['systolic array', 'systolic'],
#    'parallel processing systems': ['systolic array', 'systolic'],
#    'dynamic random access storage': ['dram'],
#    'machine learning': ['neural networks'],
#    'computer science': ['implementation',
#     'hardware',
#     'hardware implementation',
#     'low cost hardware',
#     'hardware accelerator',
#     'cost hardware implementation',
#     'cost hardware',
#     'cost hardware accelerator',
#     'inference accelerator',
#     'array accelerator',
#     'accelerator']}},
#  'W4386765220': {'syntactic': ['collaborative filtering',
#    'recommendation methods',
#    'inference',
#    'machine learning',
#    'neural networks',
#    'computational power',
#    'quantization'],
#   'semantic': ['collaborative filtering',
#    'inference',
#    'recommendation',
#    'machine learning',
#    'recommender systems',
#    'online learning',
#    'neural networks',
#    'quantizers',
#    'personalized recommendation',
#    'computational power',
#    'probabilistic inference',
#    'quantization'],
#   'union': ['collaborative filtering',
#    'recommendation methods',
#    'inference',
#    'recommendation',
#    'machine learning',
#    'recommender systems',
#    'online learning',
#    'neural networks',
#    'quantizers',
#    'personalized recommendation',
#    'computational power',
#    'probabilistic inference',
#    'quantization'],
#   'enhanced': ['recommendation algorithms',
#    'recommendation systems',
#    'inference engines',
#    'artificial intelligence',
#    'information retrieval',
#    'online systems',
#    'program processors',
#    'bayesian methods',
#    'probability distributions',
#    'image compression',
#    'signal processing'],
#   'explanation': {'collaborative filtering': ['collaborative filtering',
#     'collaborative filtering method',
#     'recommendation'],
#    'machine learning': ['neural networks', 'machine learning'],
#    'computational power': ['computational power'],
#    'recommendation methods': ['recommendation method'],
#    'neural networks': ['neural networks'],
#    'quantization': ['logarithmic quantization', 'quantization'],
#    'inference': ['machine inference', 'inference'],
#    'recommendation': ['collaborative filtering',
#     'recommendation',
#     'recommendation method'],
#    'personalized recommendation': ['collaborative filtering',
#     'recommendation',
#     'recommendation method'],
#    'recommender systems': ['collaborative filtering',
#     'collaborative filtering method',
#     'recommendation',
#     'recommendation method'],
#    'quantizers': ['logarithmic quantization', 'quantization'],
#    'probabilistic inference': ['machine inference', 'inference'],
#    'online learning': ['learning'],
#    'recommendation algorithms': ['recommendation method'],
#    'recommendation systems': ['recommendation method'],
#    'inference engines': ['machine inference', 'inference'],
#    'artificial intelligence': ['machine learning'],
#    'information retrieval': ['collaborative filtering',
#     'collaborative filtering method',
#     'recommendation',
#     'recommendation method'],
#    'online systems': ['learning'],
#    'program processors': ['computational power'],
#    'bayesian methods': ['machine inference', 'inference'],
#    'probability distributions': ['machine inference', 'inference'],
#    'image compression': ['logarithmic quantization', 'quantization'],
#    'signal processing': ['logarithmic quantization', 'quantization']}},
#  'W4293025573': {'syntactic': ['memory systems',
#    'deep learning',
#    'random bits',
#    'machine learning'],
#   'semantic': ['memory systems',
#    'background noise',
#    'memory architecture',
#    'white noise',
#    'gaussian noise (electronic)',
#    'machine learning',
#    'additive noise',
#    'deep learning',
#    'dos attacks',
#    'random access memory',
#    'parity bits',
#    'most significant bit'],
#   'union': ['memory systems',
#    'random bits',
#    'memory architecture',
#    'background noise',
#    'gaussian noise (electronic)',
#    'machine learning',
#    'white noise',
#    'deep learning',
#    'additive noise',
#    'dos attacks',
#    'random access memory',
#    'parity bits',
#    'most significant bit'],
#   'enhanced': ['dynamic random access storage',
#    'multiprocessing systems',
#    'cache memory',
#    'random number generation',
#    'information theory',
#    'field programmable gate array',
#    'multi core',
#    'parallel architectures',
#    'acoustic noise',
#    'signal to noise ratio',
#    'artificial intelligence',
#    'communication channels',
#    'neural networks',
#    'spurious signal noise',
#    'computer crime',
#    'network security',
#    'random access storage',
#    'turbo codes',
#    'distributed video coding',
#    'wyner-ziv',
#    'least significant bits'],
#   'explanation': {'machine learning': ['machine learning'],
#    'memory systems': ['memory systems', 'memory architecture'],
#    'random bits': ['random bit'],
#    'deep learning': ['deep learning'],
#    'random access memory': ['unreliable memory', 'memory'],
#    'memory architecture': ['memory systems', 'memory architecture'],
#    'most significant bit': ['bits', 'bit'],
#    'parity bits': ['bits', 'bit'],
#    'additive noise': ['noises', 'noise'],
#    'background noise': ['noises', 'noise'],
#    'gaussian noise (electronic)': ['noises', 'noise'],
#    'white noise': ['noises', 'noise'],
#    'dos attacks': ['attacks', 'attack'],
#    'dynamic random access storage': ['memory systems', 'memory architecture'],
#    'multiprocessing systems': ['memory systems', 'memory architecture'],
#    'cache memory': ['memory systems', 'memory architecture'],
#    'random number generation': ['random bit'],
#    'information theory': ['random bit'],
#    'field programmable gate array': ['memory systems', 'memory architecture'],
#    'multi core': ['memory systems', 'memory architecture'],
#    'parallel architectures': ['memory systems', 'memory architecture'],
#    'acoustic noise': ['noises', 'noise'],
#    'signal to noise ratio': ['noises', 'noise'],
#    'artificial intelligence': ['machine learning'],
#    'communication channels': ['noises', 'noise'],
#    'neural networks': ['deep learning'],
#    'spurious signal noise': ['noises', 'noise'],
#    'computer crime': ['attacks', 'attack'],
#    'network security': ['attacks', 'attack'],
#    'random access storage': ['unreliable memory', 'memory'],
#    'turbo codes': ['bits', 'bit'],
#    'distributed video coding': ['bits', 'bit'],
#    'wyner-ziv': ['bits', 'bit'],
#    'least significant bits': ['bits', 'bit']}},
#  'W4386763936': {'syntactic': ['hardware accelerators',
#    'energy-efficient',
#    'grid-based',
#    'hardware design',
#    'representation learning',
#    'gpu',
#    'point cloud',
#    'pipelined architecture'],
#   'semantic': ['hardware accelerators',
#    'computational efficiency',
#    'hardware design',
#    'co-processors',
#    'architecture designs',
#    'energy conservation',
#    'sram cell',
#    'random access memory',
#    'computer hardware',
#    'cloud services',
#    'reconfigurable hardware',
#    'gpu',
#    'point cloud',
#    'pipelined architecture'],
#   'union': ['computational efficiency',
#    'grid-based',
#    'hardware design',
#    'co-processors',
#    'sram cell',
#    'computer hardware',
#    'cloud services',
#    'representation learning',
#    'gpu',
#    'point cloud',
#    'pipelined architecture',
#    'hardware accelerators',
#    'energy-efficient',
#    'reconfigurable hardware',
#    'energy conservation',
#    'architecture designs',
#    'random access memory'],
#   'enhanced': ['theoretical computer science',
#    'grid computing',
#    'field programmable gate array',
#    'program processors',
#    'static random access storage',
#    'integrated circuits',
#    'low power',
#    'computer science',
#    'distributed database systems',
#    'commerce',
#    'cloud providers',
#    'mobile devices',
#    'computing paradigm',
#    'computing resource',
#    'computing environments',
#    'software as a service',
#    'communication',
#    'machine learning',
#    '3d data',
#    '3d modelling',
#    '3d scenes',
#    '3d object',
#    '3d objects',
#    'optical radar',
#    'pipeline processing systems',
#    'sensor networks',
#    'wireless sensor networks',
#    'telecommunication equipment',
#    'energy utilization',
#    'software architecture',
#    'random access storage'],
#   'explanation': {'point cloud': ['point-cloud', 'point cloud'],
#    'representation learning': ['feature learning'],
#    'energy-efficient': ['energy-efficient'],
#    'grid-based': ['grid-based'],
#    'hardware accelerators': ['art accelerator',
#     'learning accelerator',
#     'accelerator',
#     'hardware acceleration'],
#    'hardware design': ['hardware design', 'hardware'],
#    'pipelined architecture': ['pipelined', 'pipelined architecture'],
#    'gpu': ['gpu', 'hardware acceleration'],
#    'computer hardware': ['hardware design',
#     'hardware design level',
#     'art accelerator',
#     'hardware acceleration',
#     'learning accelerator',
#     'accelerator',
#     'hardware'],
#    'architecture designs': ['design',
#     'architecture',
#     'algorithm architecture',
#     'architecture co design',
#     'architecture co'],
#    'co-processors': ['learning accelerator', 'art accelerator', 'accelerator'],
#    'sram cell': ['sram strategy', 'transposed sram', 'sram'],
#    'cloud services': ['cloud', 'cloud feature'],
#    'energy conservation': ['energy', 'energy efficiency'],
#    'random access memory': ['large memory', 'memory'],
#    'reconfigurable hardware': ['hardware acceleration', 'hardware'],
#    'computational efficiency': ['efficiency', 'efficiency improvement'],
#    'theoretical computer science': ['efficiency', 'efficiency improvement'],
#    'grid computing': ['grid-based'],
#    'field programmable gate array': ['hardware',
#     'pipelined',
#     'art accelerator',
#     'pipelined architecture',
#     'learning accelerator',
#     'accelerator',
#     'hardware acceleration'],
#    'program processors': ['gpu',
#     'art accelerator',
#     'learning accelerator',
#     'accelerator',
#     'hardware acceleration'],
#    'static random access storage': ['sram strategy',
#     'transposed sram',
#     'sram'],
#    'integrated circuits': ['sram strategy', 'transposed sram', 'sram'],
#    'low power': ['sram strategy', 'transposed sram', 'sram'],
#    'computer science': ['hardware design level',
#     'art accelerator',
#     'learning accelerator',
#     'accelerator',
#     'hardware acceleration',
#     'hardware design',
#     'hardware'],
#    'distributed database systems': ['cloud', 'cloud feature'],
#    'commerce': ['cloud', 'cloud feature'],
#    'cloud providers': ['cloud', 'cloud feature'],
#    'mobile devices': ['cloud', 'cloud feature'],
#    'computing paradigm': ['cloud', 'cloud feature'],
#    'computing resource': ['cloud', 'cloud feature'],
#    'computing environments': ['cloud', 'cloud feature'],
#    'software as a service': ['cloud', 'cloud feature'],
#    'communication': ['cloud', 'cloud feature'],
#    'machine learning': ['feature learning'],
#    '3d data': ['point-cloud', 'point cloud'],
#    '3d modelling': ['point-cloud', 'point cloud'],
#    '3d scenes': ['point-cloud', 'point cloud'],
#    '3d object': ['point-cloud', 'point cloud'],
#    '3d objects': ['point-cloud', 'point cloud'],
#    'optical radar': ['point-cloud', 'point cloud'],
#    'pipeline processing systems': ['pipelined', 'pipelined architecture'],
#    'sensor networks': ['energy-efficient'],
#    'wireless sensor networks': ['energy-efficient'],
#    'telecommunication equipment': ['energy-efficient'],
#    'energy utilization': ['energy', 'energy efficiency'],
#    'software architecture': ['design',
#     'architecture',
#     'algorithm architecture',
#     'architecture co design',
#     'architecture co'],
#    'random access storage': ['large memory', 'memory']}},
#  'W4386763875': {'syntactic': ['encoder-decoder',
#    'inference',
#    'deep learning',
#    'area overhead'],
#   'semantic': ['parallel computation',
#    'inference',
#    'probabilistic inference',
#    'sparse approximations',
#    'sparse recovery'],
#   'union': ['parallel computation',
#    'inference',
#    'probabilistic inference',
#    'deep learning',
#    'area overhead',
#    'encoder-decoder',
#    'sparse approximations',
#    'sparse recovery'],
#   'enhanced': ['parallel algorithms',
#    'parallel computing',
#    'inference engines',
#    'bayesian methods',
#    'probability distributions',
#    'neural networks',
#    'application specific integrated circuits',
#    'programmable logic controllers',
#    'routers',
#    'embedded systems',
#    'integrated circuits',
#    'low power',
#    'approximation algorithms',
#    'signal reconstruction'],
#   'explanation': {'encoder-decoder': ['transformer', 'transformers'],
#    'inference': ['inference', 'transformer inference'],
# ...
#    'gnss receivers',
#    'glonass',
#    'classification methods',
#    'satellite system'],
#   'union': ['geostationary satellites',
#    'navigation systems',
#    'point cloud',
#    'vehicles',
#    'control point',
#    'positioning system',
#    'transmitters',
#    'gnss signals',
#    'global navigation satellite systems',
#    'gnss receivers',
#    'glonass',
#    'classification methods',
#    'satellite system'],
#   'enhanced': ['communication satellites',
#    'mobile robots',
#    '3d data',
#    '3d modelling',
#    '3d scenes',
#    '3d object',
#    '3d objects',
#    'optical radar',
#    'engineering',
#    'image coding',
#    'splines',
#    'curve fitting',
#    'signal receivers',
#    'antennas',
#    'galileo',
#    'mergers and acquisitions',
#    'satellite navigation aids',
#    'maximum likelihood estimation',
#    'computer systems'],
#   'explanation': {'vehicles': ['vehicles'],
#    'satellite system': ['satellite', 'satellite system'],
#    'classification methods': ['classification performance', 'classification'],
#    'gnss receivers': ['global navigation satellite',
#     'gnss receivers',
#     'rtk gnss',
#     'gnss'],
#    'control point': ['points', 'control points'],
#    'global navigation satellite systems': ['global navigation satellite',
#     'gnss receivers',
#     'rtk gnss',
#     'navigation satellite',
#     'gnss'],
#    'point cloud': ['surface models', 'point cloud'],
#    'positioning system': ['positioning potential',
#     'positioning',
#     'limited positioning',
#     'v positioning',
#     'positioning accuracy'],
#    'transmitters': ['receivers', 'rtk gnss receivers'],
#    'glonass': ['global navigation satellite', 'gnss'],
#    'gnss signals': ['gnss', 'gnss receivers'],
#    'navigation systems': ['global navigation satellite',
#     'positioning',
#     'navigation',
#     'navigation satellite',
#     'positioning potential',
#     'limited positioning',
#     'gnss receivers',
#     'v positioning',
#     'positioning accuracy',
#     'gnss',
#     'global navigation'],
#    'geostationary satellites': ['satellite', 'satellite system'],
#    'communication satellites': ['satellite', 'satellite system'],
#    'mobile robots': ['navigation', 'global navigation'],
#    '3d data': ['surface models', 'point cloud'],
#    '3d modelling': ['surface models', 'point cloud'],
#    '3d scenes': ['surface models', 'point cloud'],
#    '3d object': ['surface models', 'point cloud'],
#    '3d objects': ['surface models', 'point cloud'],
#    'optical radar': ['surface models', 'point cloud'],
#    'engineering': ['vehicles'],
#    'image coding': ['points', 'control points'],
#    'splines': ['points', 'control points'],
#    'curve fitting': ['points', 'control points'],
#    'signal receivers': ['receivers',
#     'global navigation satellite',
#     'rtk gnss receivers',
#     'gnss receivers',
#     'rtk gnss',
#     'gnss'],
#    'antennas': ['receivers', 'rtk gnss receivers'],
#    'galileo': ['gnss receivers', 'global navigation satellite', 'gnss'],
#    'mergers and acquisitions': ['global navigation satellite',
#     'gnss receivers',
#     'rtk gnss',
#     'gnss'],
#    'satellite navigation aids': ['global navigation satellite',
#     'gnss receivers',
#     'rtk gnss',
#     'gnss'],
#    'maximum likelihood estimation': ['global navigation satellite',
#     'gnss receivers',
#     'rtk gnss',
#     'gnss'],
#    'computer systems': ['classification performance', 'classification']}},
#  'W4387829427': {'syntactic': ['object detection method',
#    'object detection',
#    'remote sensing images',
#    'encoder-decoder'],
#   'semantic': ['remote sensing images',
#    'deep learning',
#    'object detection method',
#    'object detection',
#    'detection algorithm'],
#   'union': ['encoder-decoder',
#    'object detection method',
#    'remote sensing images',
#    'detection algorithm',
#    'object detection',
#    'deep learning'],
#   'enhanced': ['image reconstruction',
#    'signal detection',
#    'object recognition',
#    'neural networks'],
#   'explanation': {'object detection method': ['object detection methods'],
#    'object detection': ['object detection methods', 'object detection'],
#    'remote sensing images': ['remote sensing images',
#     'remote sensing',
#     'remote sensing imagery'],
#    'encoder-decoder': ['transformer-based', 'transformer'],
#    'deep learning': ['transformer-based', 'transformer', 'deep learning'],
#    'detection algorithm': ['detection methods',
#     'detectors',
#     'detector',
#     'detection'],
#    'image reconstruction': ['remote sensing images',
#     'remote sensing',
#     'remote sensing imagery'],
#    'signal detection': ['detection methods',
#     'detectors',
#     'detector',
#     'detection'],
#    'object recognition': ['object detection methods', 'object detection'],
#    'neural networks': ['transformer-based', 'transformer', 'deep learning']}},
#  'W4387802003': {'syntactic': ['high resolution remote sensing',
#    'remote sensing images',
#    'deep learning'],
#   'semantic': ['geo-spatial',
#    'remote sensing images',
#    'geo-spatial data',
#    'deep learning'],
#   'union': ['geo-spatial',
#    'remote sensing images',
#    'geo-spatial data',
#    'high resolution remote sensing',
#    'deep learning'],
#   'enhanced': ['geographic information system',
#    'image reconstruction',
#    'spatial data',
#    'image segmentation',
#    'neural networks'],
#   'explanation': {'remote sensing images': ['remote sensing images',
#     'remote sensing',
#     'high-resolution remote sensing',
#     'remote sensing imagery'],
#    'deep learning': ['deep learning'],
#    'high resolution remote sensing': ['high-resolution remote sensing'],
#    'geo-spatial': ['geographic', 'geographic information', 'vgi'],
#    'geo-spatial data': ['geographic information', 'vgi'],
#    'geographic information system': ['geographic information',
#     'geographic',
#     'vgi'],
#    'image reconstruction': ['remote sensing images',
#     'remote sensing',
#     'remote sensing imagery'],
#    'spatial data': ['geographic information', 'vgi'],
#    'image segmentation': ['high-resolution remote sensing'],
#    'neural networks': ['deep learning']}},
#  'W4312454866': {'syntactic': ['probability',
#    'recognition algorithm',
#    'random forests',
#    'regression model',
#    'boosting',
#    'artificial intelligence'],
#   'semantic': ['probability',
#    'decision tree classifiers',
#    'random forest classifier',
#    'random forest algorithm',
#    'artificial intelligence',
#    'correlation analysis',
#    'regression model',
#    'boosting',
#    'random forests'],
#   'union': ['probability',
#    'decision tree classifiers',
#    'random forest classifier',
#    'random forest algorithm',
#    'recognition algorithm',
#    'artificial intelligence',
#    'correlation analysis',
#    'regression model',
#    'boosting',
#    'random forests'],
#   'enhanced': ['mathematics',
#    'decision trees',
#    'pattern recognition',
#    'computer science',
#    'adaptive boosting'],
#   'explanation': {'random forests': ['random forest', 'gradient boosting'],
#    'probability': ['probability', 'occurrence probability'],
#    'regression model': ['regression models',
#     'linear regression',
#     'linear regression models',
#     'regression'],
#    'artificial intelligence': ['artificial intelligence'],
#    'recognition algorithm': ['recognition algorithms'],
#    'boosting': ['boosting'],
#    'random forest classifier': ['random forest'],
#    'correlation analysis': ['regression models',
#     'linear regression models',
#     'regression',
#     'linear regression',
#     'models'],
#    'random forest algorithm': ['random forest'],
#    'decision tree classifiers': ['random forest'],
#    'mathematics': ['probability',
#     'regression models',
#     'linear regression',
#     'models',
#     'occurrence probability',
#     'linear regression models'],
#    'decision trees': ['random forest', 'gradient boosting'],
#    'pattern recognition': ['recognition algorithms'],
#    'computer science': ['artificial intelligence'],
#    'adaptive boosting': ['boosting']}},
#  'W4387803858': {'syntactic': ['encoder-decoder',
#    'low resolution',
#    'generative adversarial networks',
#    'superresolution',
#    'deep learning',
#    'neural networks'],
#   'semantic': ['low resolution',
#    'geostationary satellites',
#    'superresolution',
#    'deep learning',
#    'neural networks',
#    'low resolution images',
#    'satellite system'],
#   'union': ['encoder-decoder',
#    'low resolution',
#    'geostationary satellites',
#    'generative adversarial networks',
#    'superresolution',
#    'deep learning',
#    'neural networks',
#    'low resolution images',
#    'satellite system'],
#   'enhanced': ['communication satellites',
#    'adversarial machine learning',
#    'optical resolving power',
#    'machine learning',
#    'high resolution image'],
#   'explanation': {'generative adversarial networks': ['generative adversarial networks'],
#    'superresolution': ['low resolution',
#     'super-resolution',
#     'super resolution',
#     'high resolution',
#     'low resolution images'],
#    'encoder-decoder': ['transformers'],
#    'low resolution': ['low resolution',
#     'high resolution',
#     'low resolution images'],
#    'deep learning': ['transformers', 'deep learning'],
#    'neural networks': ['transformers',
#     'generative adversarial networks',
#     'neural networks',
#     'deep learning'],
#    'satellite system': ['other satellite',
#     'satellite',
#     'resolution satellite',
#     'satellite images'],
#    'geostationary satellites': ['other satellite',
#     'satellite',
#     'resolution satellite',
#     'satellite images'],
#    'low resolution images': ['low resolution', 'low resolution images'],
#    'communication satellites': ['resolution satellite',
#     'satellite images',
#     'other satellite',
#     'satellite'],
#    'adversarial machine learning': ['generative adversarial networks'],
#    'optical resolving power': ['low resolution',
#     'super-resolution',
#     'super resolution',
#     'high resolution',
#     'low resolution images'],
#    'machine learning': ['transformers',
#     'generative adversarial networks',
#     'neural networks',
#     'deep learning'],
#    'high resolution image': ['low resolution', 'low resolution images']}},
#  'W4387828738': {'syntactic': ['fused images'],
#   'semantic': ['high resolution image',
#    'image pairs',
#    'reference image',
#    'digital image',
#    'color images'],
#   'union': ['high resolution image',
#    'image pairs',
#    'fused images',
#    'digital image',
#    'color images',
#    'reference image'],
#   'enhanced': ['superresolution',
#    'imaging systems',
#    'image matching',
#    'image fusion',
#    'image analysis',
#    'image processing',
#    'pattern recognition',
#    'color image processing',
#    'image quality'],
#   'explanation': {'fused images': ['fused image'],
#    'color images': ['images', 'image'],
#    'reference image': ['images', 'image'],
#    'digital image': ['images', 'image'],
#    'high resolution image': ['images'],
#    'image pairs': ['images'],
#    'superresolution': ['images'],
#    'imaging systems': ['images'],
#    'image matching': ['images', 'image'],
#    'image fusion': ['fused image'],
#    'image analysis': ['images', 'image'],
#    'image processing': ['images', 'image'],
#    'pattern recognition': ['images', 'image'],
#    'color image processing': ['images', 'image'],
#    'image quality': ['images', 'image']}},
#  'W4387829540': {'syntactic': ['correlation coefficient',
#    'optimization problems',
#    'mean square',
#    'retrieval performance',
#    'sensors',
#    'microwaves'],
#   'semantic': ['geostationary satellites',
#    'optimization',
#    'frequency bands',
#    'sensors',
#    'microwaves',
#    'satellite system'],
#   'union': ['retrieval performance',
#    'geostationary satellites',
#    'correlation coefficient',
#    'optimization problems',
#    'mean square',
#    'optimization',
#    'frequency bands',
#    'sensors',
#    'microwaves',
#    'satellite system'],
#   'enhanced': ['information retrieval systems',
#    'communication satellites',
#    'correlation analysis',
#    'sufficient conditions',
#    'mean square error',
#    'stochastic processes',
#    'mathematics',
#    'antennas',
#    'computer hardware',
#    'signal processing'],
#   'explanation': {'retrieval performance': ['retrieval model'],
#    'microwaves': ['microwave',
#     'microwave radiation',
#     'microwave sensor',
#     'passive microwave',
#     'multiband microwave'],
#    'sensors': ['sensor', 'sensing'],
#    'optimization problems': ['optimization algorithm'],
#    'mean square': ['mean square'],
#    'correlation coefficient': ['correlation coefficient'],
#    'optimization': ['optimization'],
#    'frequency bands': ['multi band', 'band temperature', 'band'],
#    'satellite system': ['3d satellite', 'satellite', 'optical satellite'],
#    'geostationary satellites': ['3d satellite',
#     'satellite',
#     'optical satellite'],
#    'information retrieval systems': ['retrieval model'],
#    'communication satellites': ['3d satellite',
#     'satellite',
#     'optical satellite'],
#    'correlation analysis': ['optimization algorithm',
#     'correlation coefficient'],
#    'sufficient conditions': ['mean square'],
#    'mean square error': ['mean square'],
#    'stochastic processes': ['mean square'],
#    'mathematics': ['optimization'],
#    'antennas': ['multi band', 'band temperature', 'band'],
#    'computer hardware': ['sensor', 'sensing'],
#    'signal processing': ['microwave',
#     'microwave radiation',
#     'microwave sensor',
#     'passive microwave',
#     'multiband microwave']}},
#  'W4387803370': {'syntactic': ['sar system',
#    'automatic identification system'],
#   'semantic': ['automatic identification',
#    'synthetic aperture radar',
#    'sar images',
#    'automatic identification system',
#    'frequency bands'],
#   'union': ['automatic identification',
#    'synthetic aperture radar',
#    'sar images',
#    'automatic identification system',
#    'frequency bands',
#    'sar system'],
#   'enhanced': ['automation',
#    'imaging systems',
#    'radar',
#    'synthetic apertures',
#    'radar antennas',
#    'electronic data interchange',
#    'antennas',
#    'space-borne',
#    'polarimeters'],
#   'explanation': {'sar system': ['sar system'],
#    'automatic identification system': ['automatic identification system'],
#    'frequency bands': ['c band', 'band data', 'band', 'band sar'],
#    'automatic identification': ['automatic identification'],
#    'synthetic aperture radar': ['sar'],
#    'sar images': ['sar system', 'sar'],
#    'automation': ['automatic identification'],
#    'imaging systems': ['sar'],
#    'radar': ['sar'],
#    'synthetic apertures': ['sar'],
#    'radar antennas': ['sar'],
#    'electronic data interchange': ['automatic identification system'],
#    'antennas': ['c band', 'band data', 'band', 'band sar'],
#    'space-borne': ['sar system'],
#    'polarimeters': ['sar system']}},
#  'W4312979458': {'syntactic': ['encoder-decoder',
#    'radar',
#    'semantic information',
#    'deep learning',
#    'semantic levels',
#    'http'],
#   'semantic': ['radar systems',
#    'radar',
#    'semantics',
#    'semantic information',
#    'deep learning'],
#   'union': ['encoder-decoder',
#    'radar',
#    'radar systems',
#    'semantics',
#    'semantic information',
#    'deep learning',
#    'semantic levels',
#    'http'],
#   'enhanced': ['signal processing',
#    'computer hardware',
#    'radar imaging',
#    'neural networks',
#    'ontology',
#    'information theory',
#    'servers',
#    'client server computer systems',
#    'internet protocols'],
#   'explanation': {'deep learning': ['transformer', 'deep learning'],
#    'radar': ['radar'],
#    'encoder-decoder': ['transformer'],
#    'http': ['http'],
#    'semantic information': ['semantic', 'semantic features'],
#    'semantic levels': ['semantic level'],
#    'radar systems': ['radar observations',
#     'radar',
#     'radar variables',
#     'polarization radar'],
#    'semantics': ['semantic', 'semantic features'],
#    'signal processing': ['radar'],
#    'computer hardware': ['radar'],
#    'radar imaging': ['radar observations',
#     'radar',
#     'radar variables',
#     'polarization radar'],
#    'neural networks': ['transformer', 'deep learning'],
#    'ontology': ['semantic level'],
#    'information theory': ['semantic level'],
#    'servers': ['http'],
#    'client server computer systems': ['http'],
#    'internet protocols': ['http']}},
#  ...}
